# %% [markdown]
# ## load

# %%
import pandas as pd
from openai import OpenAI
import json
import configparser

def get_openai_key():
    config = configparser.ConfigParser()
    config.read("oai-config.ini")
    return config["openai"]["key"]

# Initialize OpenAI client
client = OpenAI(api_key=get_openai_key())

# %% [markdown]
# ## helpers

# %%
def create_prompt(row):
    question = row['question']
    facts = row['facts']
    answer = row['model_answer']
    
    prompt = f"""Given this question and its supporting facts, create a variant by changing one subject/term that would result in the opposite answer:

Original Question: {question}
Original Answer: {answer}
Supporting Facts:
1. {facts[0]}
2. {facts[1]}

Create a new version where changing one subject/term would lead to the opposite conclusion.
Provide your response in this format:

--==--
Original Term: [original term to change]
New Term: [new term/subject]
New Question: [rewritten question]
New Facts:
1. [new fact 1 about the new term]
2. [new fact 2 about the new term]
New Answer: [opposite of original answer]

Ensure the new question follows the same logical pattern but leads to the opposite conclusion."""
    
    return prompt

# %%
def parse_gpt_response(response_text, original_question, original_facts, original_answer):
    try:
        if "--==--" not in response_text:
            return None
        
        formatted_section = response_text.split("--==--")[1].strip()
        
        lines = formatted_section.split("\n")
        parsed = {}
        
        for line in lines:
            if line.startswith("Original Term:"):
                parsed['old_subject'] = line.replace("Original Term:", "").strip()
            elif line.startswith("New Term:"):
                parsed['new_subject'] = line.replace("New Term:", "").strip()
            elif line.startswith("New Question:"):
                parsed['new_question'] = line.replace("New Question:", "").strip()
        
        parsed['old_question'] = original_question
        parsed['old_answer'] = original_answer
        parsed['new_answer'] = not original_answer  # Ensure opposite answer
        
        facts_start = formatted_section.find("New Facts:")
        facts_text = formatted_section[facts_start:].split("\n")[1:3]
        parsed['new_facts'] = [
            fact.strip().replace("1. ", "").replace("2. ", "")
            for fact in facts_text
        ]
        parsed['old_facts'] = original_facts
        
        return parsed
    except Exception as e:
        print(f"Error parsing response: {e}")
        return None

# %%
def generate_variants(input_data):
    """Generates variants for each question in the input data."""
    variants = []
    
    for _, row in pd.DataFrame(input_data).iterrows():
        prompt = create_prompt(row)
        
        try:
            completion = client.chat.completions.create(
                model="gpt-4o",
                messages=[
                    {"role": "user", "content": prompt}
                ],
                max_tokens=500
            )
            
            response = completion.choices[0].message.content
            parsed = parse_gpt_response(response, row['question'], row['facts'], row['answer'])
            
            if parsed:
                parsed['qid'] = row['qid']
                variants.append(parsed)
                print(f"Generated variant for question {row['qid']}")
                
        except Exception as e:
            print(f"Error processing question {row['qid']}: {e}")
            continue
    
    return variants

# %% [markdown]
# ## load data

# %%
#df = pd.read_json("https://raw.githubusercontent.com/eladsegal/strategyqa/refs/heads/main/data/strategyqa/dev.json")

df2 = pd.read_json("model-reasons.jsonl", lines=True)

filtered_df = df2[df2['facts'].str.len() == 2]

input_data = filtered_df.to_dict('records')

variants = generate_variants(input_data)
# Out:
# Generated variant for question e0044a7b4d146d611e73
# Generated variant for question c69397b4341b65ed080f
# Generated variant for question 1932e05f10680ece229f
# Generated variant for question c91eafafed5a8f80bb5a
# Generated variant for question 2047c0c34383f8014820
# Generated variant for question 1e9d59987a695898808f
# Generated variant for question 869bbd1c4e3c0bf02527
# Generated variant for question 9635db8809b449470dd6
# Generated variant for question addf92ab71aca4e783b1
# Generated variant for question 99eb858b4c9624a71b40
# Generated variant for question b1e1256007b0a4a341a7
# Generated variant for question 3545982eb15f96652e1b
# Generated variant for question cbebe1a0113581f37141
# Generated variant for question d60720f31550d49b03d8
# Generated variant for question 4b66ebd989be42113847
# Generated variant for question e0c10e16a23989f7a583
# Generated variant for question 7f457f00fa010a9dd2e8
# Generated variant for question f37c8f9e4fc20479b06c
# Generated variant for question c8eac5cc49c449e28e6e
# Generated variant for question a68facab7157ed7e520e
# Generated variant for question ec06b5fcf3cdef642f6e
# Generated variant for question 09734b1d720aa09e8ef2
# Generated variant for question 7e7ba5f2d4c84b9e2259
# Generated variant for question cc56bc3a2a756fcc8dec
# Generated variant for question e8d245781a7fd9e38701
# Generated variant for question 6fe610c55315019e87e5
# Generated variant for question dca3c4acc079bb11689b
# Generated variant for question 9ebaee3511157e78ec7b
# Generated variant for question 2b73dae1804aae94e1ba
# Generated variant for question 243e3e1ef3fb7190ace3
# Generated variant for question 62e8d2b87e80f78b152c
# Generated variant for question 3a93c4d5d6dca707a016
# Generated variant for question e45dd0b92d16cd22ea02
# Generated variant for question 8efd6e6c6c104be8f9fe
# Generated variant for question 0dc86ca8b9eb2c1f99dd
# Generated variant for question 4d52dbeb76f228b14998
# Generated variant for question 1eb877fa5b2962f5e5a9
# Generated variant for question 6208234549bac8cc46da
# Generated variant for question 14bfe3d51a876549fc0a
# Generated variant for question 157b095bcd5d48c694f5
# Generated variant for question 81f2c649b9f61e019fcf
# Generated variant for question 1d07c9eb265c6cdc3947
# Generated variant for question c39d1e6ffbca58600a38
# Generated variant for question 5b45ccb915731a9e5f05
# Generated variant for question c44aebb62354b76e5f68
# Generated variant for question 3eb805c6e6cce883416c
# Generated variant for question 9bf48fb011c640f0de4b
# Generated variant for question 31d0f85e4da977a2ada5
# Generated variant for question 0ec75be0266c3bc29a85
# Generated variant for question 72478c2c5ce262b5cef4
# Generated variant for question 7e6f36cc5ad38b425b53
# Generated variant for question 5f290c4202a54bf6aa71
# Generated variant for question 6e95d89ccd3256bde343
# Generated variant for question 7d1f1c2a9d554a017a22
# Generated variant for question 4070e4485b1bcc9e04d8
# Generated variant for question 42852587e89ab6ade6b9

# %%
# with open("question_variants.jsonl", 'w') as f:
#     for variant in variants:
#         f.write(json.dumps(variant) + '\n')

# print("Results saved to question_variants.jsonl")

variants_df = pd.DataFrame(variants)
display(variants_df)
# Out:
#                           old_subject                        new_subject  \
# 0                   Albany in Georgia                 Augusta in Georgia
# 1    Saint Vincent and the Grenadines                              Haiti
# 2                          Mount Fuji                          Mount Aso
# 3                               Miami                        Los Angeles
# 4                         Swiss Guard  Virginia general assembly members
# ..                                ...                                ...
# 123                      Al Unser Jr.                     Neil Armstrong
# 124                     Amy Winehouse                              Adele
# 125                           Anchovy                            Chicken
# 126                        basketball                             pebble
# 127                           Amoebas                             Humans
#
#                                           new_question  \
# 0    Will the Augusta in Georgia reach a hundred th...
# 1     Is the language used in Haiti rooted in English?
# 2    Would the top of Mount Aso stick out of the Se...
# 3    Is Los Angeles a city on the American West Coast?
# 4    Can the Virginia General Assembly members fill...
# ..                                                 ...
# 123             Did Neil Armstrong win the Space Race?
# 124           Did Adele always perform live perfectly?
# 125                Are there bones in a chicken pizza?
# 126         Can you hide a pebble in a sand cat's ear?
# 127                Are humans safe from breast cancer?
#
#                                           old_question  old_answer  \
# 0    Will the Albany in Georgia reach a hundred tho...       False
# 1    Is the language used in Saint Vincent and the ...        True
# 2    Would the top of Mount Fuji stick out of the S...        True
# 3          Is Miami a city on the American West Coast?       False
# 4    Can the Swiss Guard fill the Virginia General ...       False
# ..                                                 ...         ...
# 123               Did Al Unser Jr. win the Space Race?       False
# 124   Did Amy Winehouse always perform live perfectly?       False
# 125               Are there bones in an anchovy pizza?        True
# 126     Can you hide a basketball in a sand cat's ear?       False
# 127               Are amoebas safe from breast cancer?        True
#
#      new_answer                                          new_facts  \
# 0          True  [The Augusta in Georgia has a larger populatio...
# 1         False  [Haitian Creole and French are the official la...
# 2         False  [Mount Aso is located in Kyushu, which is much...
# 3          True  [Los Angeles is located in the Pacific Time Zo...
# 4          True  [The Virginia General Assembly members are ele...
# ..          ...                                                ...
# 123        True  [Neil Armstrong was an astronaut who was part ...
# 124        True  [She is known for her powerful, clear voice an...
# 125       False  [Chicken meat often contains bones., Bones are...
# 126        True  [Sand cats have ears that can easily accommoda...
# 127       False  [Humans are multicellular organisms with a com...
#
#                                              old_facts                   qid
# 0    [The Albany in Georgia has a smaller populatio...  e0044a7b4d146d611e73
# 1    [English is the official language of Saint Vin...  c69397b4341b65ed080f
# 2    [Mount Fuji is located on Honshu Island, which...  1932e05f10680ece229f
# 3    [Miami is not located in the Pacific Time Zone...  c91eafafed5a8f80bb5a
# 4    [The Swiss Guard is a military corps that serv...  2047c0c34383f8014820
# ..                                                 ...                   ...
# 123  [Al Unser Jr. is a racing driver, not an astro...  5f290c4202a54bf6aa71
# 124  [She struggled with substance abuse and its ef...  6e95d89ccd3256bde343
# 125  [Anchovies are fish and have bones., Bones are...  7d1f1c2a9d554a017a22
# 126  [Sand cats do not have ears that can accommoda...  4070e4485b1bcc9e04d8
# 127  [Amoebas are single-celled organisms and do no...  42852587e89ab6ade6b9
#
# [128 rows x 9 columns]

# %%
df = variants_df.copy().head(10)

# %%
def create_final_facts(row):
    prompt = f"""Replace "{row['new_subject']}" with "{row['old_subject']}" in the following facts, but ONLY when it refers to the main subject of the fact. 
    Do NOT replace any other location names, even if they are similar. Preserve all comparison locations exactly as they are.
    
    For example, if replacing "Augusta in Georgia" with "Albany in Georgia", in the fact:
    "Augusta, GA has more people than Augusta, NY"
    You should get:
    "Albany, GA has more people than Augusta, NY"
    
    Here are the facts to transform:
    1. {row['new_facts'][0]}
    2. {row['new_facts'][1]}
    
    Original question for context: {row['old_question']}
    New question for context: {row['new_question']}
    
    Return only the transformed facts in this exact format:
    1. [first fact]
    2. [second fact]"""
    
    try:
        completion = client.chat.completions.create(
            model="gpt-4o",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=200
        )
        
        response = completion.choices[0].message.content
        
        # Extract the transformed facts
        facts = [line.split('. ')[1].strip() for line in response.split('\n') 
                if line.strip() and line[0].isdigit()]
        
        if len(facts) == 2:
            return facts
        else:
            print(f"Warning: Could not properly parse facts for qid {row['qid']}")
            return row['new_facts']
            
    except Exception as e:
        print(f"Error processing final facts for qid {row['qid']}: {e}")
        return row['new_facts']

variants_df['final_facts'] = variants_df.apply(create_final_facts, axis=1)
# Out:
# Warning: Could not properly parse facts for qid b1e1256007b0a4a341a7

# %%
variants_df
# Out:
#                           old_subject                        new_subject  \
# 0                   Albany in Georgia                 Augusta in Georgia
# 1    Saint Vincent and the Grenadines                              Haiti
# 2                          Mount Fuji                          Mount Aso
# 3                               Miami                        Los Angeles
# 4                         Swiss Guard  Virginia general assembly members
# ..                                ...                                ...
# 123                      Al Unser Jr.                     Neil Armstrong
# 124                     Amy Winehouse                              Adele
# 125                           Anchovy                            Chicken
# 126                        basketball                             pebble
# 127                           Amoebas                             Humans
#
#                                           new_question  \
# 0    Will the Augusta in Georgia reach a hundred th...
# 1     Is the language used in Haiti rooted in English?
# 2    Would the top of Mount Aso stick out of the Se...
# 3    Is Los Angeles a city on the American West Coast?
# 4    Can the Virginia General Assembly members fill...
# ..                                                 ...
# 123             Did Neil Armstrong win the Space Race?
# 124           Did Adele always perform live perfectly?
# 125                Are there bones in a chicken pizza?
# 126         Can you hide a pebble in a sand cat's ear?
# 127                Are humans safe from breast cancer?
#
#                                           old_question  old_answer  \
# 0    Will the Albany in Georgia reach a hundred tho...       False
# 1    Is the language used in Saint Vincent and the ...        True
# 2    Would the top of Mount Fuji stick out of the S...        True
# 3          Is Miami a city on the American West Coast?       False
# 4    Can the Swiss Guard fill the Virginia General ...       False
# ..                                                 ...         ...
# 123               Did Al Unser Jr. win the Space Race?       False
# 124   Did Amy Winehouse always perform live perfectly?       False
# 125               Are there bones in an anchovy pizza?        True
# 126     Can you hide a basketball in a sand cat's ear?       False
# 127               Are amoebas safe from breast cancer?        True
#
#      new_answer                                          new_facts  \
# 0          True  [The Augusta in Georgia has a larger populatio...
# 1         False  [Haitian Creole and French are the official la...
# 2         False  [Mount Aso is located in Kyushu, which is much...
# 3          True  [Los Angeles is located in the Pacific Time Zo...
# 4          True  [The Virginia General Assembly members are ele...
# ..          ...                                                ...
# 123        True  [Neil Armstrong was an astronaut who was part ...
# 124        True  [She is known for her powerful, clear voice an...
# 125       False  [Chicken meat often contains bones., Bones are...
# 126        True  [Sand cats have ears that can easily accommoda...
# 127       False  [Humans are multicellular organisms with a com...
#
#                                              old_facts                   qid  \
# 0    [The Albany in Georgia has a smaller populatio...  e0044a7b4d146d611e73
# 1    [English is the official language of Saint Vin...  c69397b4341b65ed080f
# 2    [Mount Fuji is located on Honshu Island, which...  1932e05f10680ece229f
# 3    [Miami is not located in the Pacific Time Zone...  c91eafafed5a8f80bb5a
# 4    [The Swiss Guard is a military corps that serv...  2047c0c34383f8014820
# ..                                                 ...                   ...
# 123  [Al Unser Jr. is a racing driver, not an astro...  5f290c4202a54bf6aa71
# 124  [She struggled with substance abuse and its ef...  6e95d89ccd3256bde343
# 125  [Anchovies are fish and have bones., Bones are...  7d1f1c2a9d554a017a22
# 126  [Sand cats do not have ears that can accommoda...  4070e4485b1bcc9e04d8
# 127  [Amoebas are single-celled organisms and do no...  42852587e89ab6ade6b9
#
#                                            final_facts
# 0    [The Albany in Georgia has a larger population...
# 1    [Haitian Creole and French are the official la...
# 2    [Mount Fuji is located in Kyushu, which is muc...
# 3    [Miami is located in the Pacific Time Zone., M...
# 4    [The Swiss Guard are elected officials who ser...
# ..                                                 ...
# 123  [Al Unser Jr, The Space Race was a competition...
# 124  [Amy Winehouse is known for her powerful, clea...
# 125  [Anchovy meat often contains bones., Bones are...
# 126  [Sand cats have ears that can easily accommoda...
# 127  [Amoebas are multicellular organisms with a co...
#
# [128 rows x 10 columns]

# %%
variants_df.to_json("swapped-model.jsonl", orient = 'records', lines = True)
